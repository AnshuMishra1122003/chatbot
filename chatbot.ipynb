# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshuMishra1122003/chatbot/blob/master/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# fine_tuned_model_new/db_utils.py
import json
import os

SCHEMA_FILE = "database_schema.json"

def load_database_schema():
    """Load database schema from a JSON file."""
    if not os.path.exists(SCHEMA_FILE):
        print(f"❌ Error: Schema file '{SCHEMA_FILE}' not found!")
        return {}

    try:
        with open(SCHEMA_FILE, "r") as file:
            schema = json.load(file)
            if not isinstance(schema, list):
                print("❌ Error: Invalid schema format! Missing 'tables' key.")
                return {}
            return schema
    except json.JSONDecodeError:
        print("❌ Error: JSON format is invalid!")
        return {}

# Fetch schema
database_schema = load_database_schema()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-a219e39ac332> in <cell line: 0>()
#      35
#      36 # ✅ Add parent directory to sys.path
# ---> 37 import load_database_schema
#      38
#      39 # Load schema
#
# ModuleNotFoundError: No module named 'load_database_schema'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import json
import os
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
import sys
import warnings
from torch.utils.data import DataLoader, TensorDataset

# Suppress 'past_key_values' warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*past_key_values.*")

SCHEMA_FILE = "database_schema.json"

def load_database_schema():
    """Load database schema from a JSON file."""
    if not os.path.exists(SCHEMA_FILE):
        print(f"❌ Error: Schema file '{SCHEMA_FILE}' not found!")
        return []

    try:
        with open(SCHEMA_FILE, "r") as file:
            schema = json.load(file)
            if not isinstance(schema, list):
                print("❌ Error: Invalid schema format! Expected a list.")
                return []
            return schema
    except json.JSONDecodeError:
        print("❌ Error: JSON format is invalid!")
        return []

# Load database schema
database_schema = load_database_schema()
if not database_schema:
    print("❌ Error: No valid database schema found. Exiting training.")
    sys.exit(1)

# Upgrade model from t5-small → t5-base
MODEL_NAME = "t5-base"
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)

max_length = 256  # Reduced max_length for efficiency
batch_size = 4  # Adjust batch size for memory optimization
gradient_accumulation_steps = 4  # Accumulate gradients to simulate a larger batch

# Prepare training data
training_data = []
for query_data in database_schema:
    title = query_data.get("title", "Unknown Title")
    queries = query_data.get("queries", [])

    if not queries:
        print(f"⚠️ Warning: No queries found for '{title}', skipping...")
        continue

    sql_query = queries[0]  # Extract first query
    training_data.append({"input": title, "output": sql_query})

if not training_data:
    print("❌ Error: No training data generated from schema.")
    sys.exit(1)

print(f"✅ Training Data Loaded: {len(training_data)} queries ready for training.")

# Compute max token length **after** training_data is built
max_query_length = max(len(tokenizer.encode(d["output"], add_special_tokens=True)) for d in training_data)
print(f"📝 Max token length for queries: {max_query_length}")

# Convert training data to tokenized format
train_encodings = tokenizer(
    [d["input"] for d in training_data], padding=True, truncation=True, max_length=max_length, return_tensors="pt"
)
train_labels = tokenizer(
    [d["output"] for d in training_data], padding=True, truncation=True, max_length=max_length, return_tensors="pt"
)

# Create a DataLoader for batching
train_dataset = TensorDataset(train_encodings["input_ids"], train_labels["input_ids"])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-5)

# Mixed Precision (AMP) for faster training
from torch.cuda.amp import autocast, GradScaler
scaler = GradScaler()

# Training loop with gradient accumulation
for epoch in range(10):
    model.train()
    total_loss = 0
    optimizer.zero_grad()

    for step, batch in enumerate(train_dataloader):
        input_ids, labels = [b.to(device) for b in batch]

        with autocast():
            outputs = model(input_ids=input_ids, labels=labels)
            loss = outputs.loss / gradient_accumulation_steps  # Scale loss

        scaler.scale(loss).backward()

        if (step + 1) % gradient_accumulation_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        total_loss += loss.item() * gradient_accumulation_steps  # Scale back loss

    avg_loss = total_loss / len(train_dataloader)
    print(f"✅ Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

# Save the fine-tuned model
model_path = os.path.join(os.getcwd(), "fine_tuned_sql_model")
os.makedirs(model_path, exist_ok=True)

model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

print(f"✅ Model training completed and saved at: {model_path}")
# Out:
# ⚠️ Warning: No queries found for 'CrowdStrike - Compliance', skipping...
# ⚠️ Warning: No queries found for 'JAMF - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Unknown', skipping...
# ⚠️ Warning: No queries found for 'Sapphire Compliance', skipping...
# ⚠️ Warning: No queries found for 'Server Compliance', skipping...
# ⚠️ Warning: No queries found for 'Device42 Compliance', skipping...
# ⚠️ Warning: No queries found for 'Unknown', skipping...
# ⚠️ Warning: No queries found for 'Sapphire Compliance', skipping...
# ⚠️ Warning: No queries found for 'Server Compliance', skipping...
# ⚠️ Warning: No queries found for 'Device42 Compliance', skipping...
# ⚠️ Warning: No queries found for 'CrowdStrike - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Crowdstrike Summary', skipping...
# ⚠️ Warning: No queries found for 'Workstation Discrepancy Count', skipping...
# ⚠️ Warning: No queries found for 'Server-Non Compliance', skipping...
# ⚠️ Warning: No queries found for 'Endpoint - Non Compliance', skipping...
# ⚠️ Warning: No queries found for 'PAM - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Bigfix - Compliance', skipping...
# ⚠️ Warning: No queries found for 'CrowdStrike - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Endpoint Trends', skipping...
# ⚠️ Warning: No queries found for 'Server Trends', skipping...
# ⚠️ Warning: No queries found for 'Device42 Trends', skipping...
# ⚠️ Warning: No queries found for 'JAMF Trends', skipping...
# ⚠️ Warning: No queries found for 'JAMF CrowdStrike - Compliance', skipping...
# ⚠️ Warning: No queries found for 'JAMF Sapphire - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Unknown', skipping...
# ⚠️ Warning: No queries found for 'SOC - Compliance (Calculated using unique IP Address)', skipping...
# ⚠️ Warning: No queries found for 'CrowdStrike - Compliance', skipping...
# ⚠️ Warning: No queries found for 'CrowdStrike - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Unknown', skipping...
# ⚠️ Warning: No queries found for 'ZScaler Summary', skipping...
# ⚠️ Warning: No queries found for 'Force Point Data Classification - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Crowdstrike Discrepancy', skipping...
# ⚠️ Warning: No queries found for 'ZScaler Discrepancy', skipping...
# ⚠️ Warning: No queries found for 'Qualys Discrepancy', skipping...
# ⚠️ Warning: No queries found for 'AD Discrepancy - Manual Inventory', skipping...
# ⚠️ Warning: No queries found for 'AD Devices Discrepancy - API', skipping...
# ⚠️ Warning: No queries found for 'ForcePoint - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Force Point - Compliance', skipping...
# ⚠️ Warning: No queries found for 'ForcePoint Data Classification - Compliance', skipping...
# ⚠️ Warning: No queries found for 'PAM - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Unknown', skipping...
# ⚠️ Warning: No queries found for 'Sapphire Compliance', skipping...
# ⚠️ Warning: No queries found for 'JAMF Compliance', skipping...
# ⚠️ Warning: No queries found for 'Server Compliance', skipping...
# ⚠️ Warning: No queries found for 'Device42 Compliance', skipping...
# ⚠️ Warning: No queries found for 'Bigfix Endpoint - Compliance', skipping...
# ⚠️ Warning: No queries found for 'Bigfix - Compliance', skipping...
# ✅ Training Data Loaded: 394 queries ready for training.
# 📝 Max token length for queries: 1225
# <ipython-input-2-399b37254a8e>:90: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /usr/local/lib/python3.11/dist-packages/torch/amp/grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# <ipython-input-2-399b37254a8e>:101: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /usr/local/lib/python3.11/dist-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-399b37254a8e> in <cell line: 0>()
#     103             loss = outputs.loss / gradient_accumulation_steps  # Scale loss
#     104
# --> 105         scaler.scale(loss).backward()
#     106
#     107         if (step + 1) % gradient_accumulation_steps == 0:
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# fine_tuned_model_new/db_utils.py
import json
import os

SCHEMA_FILE = "database_schema.json"

def load_database_schema():
    """Load database schema from a JSON file."""
    if not os.path.exists(SCHEMA_FILE):
        print(f"❌ Error: Schema file '{SCHEMA_FILE}' not found!")
        return {}

    try:
        with open(SCHEMA_FILE, "r") as file:
            schema = json.load(file)
            if not isinstance(schema, list):
                print("❌ Error: Invalid schema format! Missing 'tables' key.")
                return {}
            return schema
    except json.JSONDecodeError:
        print("❌ Error: JSON format is invalid!")
        return {}

# Fetch schema
database_schema = load_database_schema()


with open(SCHEMA_FILE, "r") as f:
    schema = json.load(f)

# Ensure the database_folder exists
os.makedirs("database_folder", exist_ok=True)

# Split schema into 30 parts
num_parts = 5
part_size = len(schema) // num_parts
schema_parts = [schema[i * part_size: (i + 1) * part_size] for i in range(num_parts - 1)]
schema_parts.append(schema[(num_parts - 1) * part_size:])  # Add remaining data to the last part

# Save each part separately
for i, part in enumerate(schema_parts):
    part_path = f"database_folder/database_schema_part_{i+1}.json"
    with open(part_path, "w") as f:
        json.dump(part, f, indent=4)
    print(f"✅ Part {i+1} saved at {part_path}")

print("✅ Schema successfully split into 30 parts!")
# Out:
# ✅ Part 1 saved at database_folder/database_schema_part_1.json
# ✅ Part 2 saved at database_folder/database_schema_part_2.json
# ✅ Part 3 saved at database_folder/database_schema_part_3.json
# ✅ Part 4 saved at database_folder/database_schema_part_4.json
# ✅ Part 5 saved at database_folder/database_schema_part_5.json
# ✅ Schema successfully split into 30 parts!

# %%
import json
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
import os
import sys
import warnings
from torch.utils.data import DataLoader, TensorDataset

# Filter warnings related to past_key_values
warnings.filterwarnings("ignore", category=UserWarning, message=".*past_key_values.*")

# Add parent directory to sys.path (Fixed for Colab)
sys.path.append(os.path.abspath(".."))

# Directory containing schema parts
SCHEMA_DIR = "database_folder"
MODEL_BASE_PATH = "fine_tuned_models"

os.makedirs(MODEL_BASE_PATH, exist_ok=True)  # Ensure model save directory exists

# Upgrade model from t5-small → t5-base
MODEL_NAME = "t5-base"
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)

batch_size = 2 # Adjust batch size for memory optimization
num_epochs = 100  # Define number of epochs
early_stop_loss_threshold = 0.5  # Stop training early if loss is below this

# Get all schema part files
schema_files = sorted([f for f in os.listdir(SCHEMA_DIR) if f.startswith("database_schema_part_")])

for idx, schema_file in enumerate(schema_files):
    schema_path = os.path.join(SCHEMA_DIR, schema_file)

    # Load schema part
    with open(schema_path, "r") as f:
        database_schema = json.load(f)

    if not database_schema:
        print(f"❌ Error: No valid data found in {schema_file}. Skipping...")
        continue

    # Prepare training data using SQL queries
    training_data = []
    max_query_length = 0  # Track max query length dynamically

    for query_data in database_schema:
        title = query_data.get("title", "Unknown Title")  # Default title if missing
        queries = query_data.get("queries", [])  # Get queries list (default: empty list)

        if not queries:
            print(f"⚠️ Warning: No queries found for '{title}', skipping...")
            continue

        sql_query = queries[0]  # Extract first query safely
        training_data.append({"input": title, "output": sql_query})

        # Update max_length dynamically
        query_length = len(tokenizer.encode(sql_query, add_special_tokens=True))
        max_query_length = max(max_query_length, query_length)

    if not training_data:
        print(f"❌ Error: No training data generated from {schema_file}. Skipping...")
        continue

    # Set dynamic max_length (cap at 1024 to prevent memory issues)
    max_length = min(max_query_length, 1225)

    print(f"✅ Training Data Loaded from {schema_file}: {len(training_data)} queries ready for training.")
    print(f"🔹 Using max_length={max_length} for this schema part.")

    # Convert training data to tokenized format
    train_encodings = tokenizer(
        [d["input"] for d in training_data], padding=True, truncation=True, max_length=max_length, return_tensors="pt"
    )
    train_labels = tokenizer(
        [d["output"] for d in training_data], padding=True, truncation=True, max_length=max_length, return_tensors="pt"
    )

    # Create DataLoader
    train_dataset = TensorDataset(train_encodings["input_ids"], train_labels["input_ids"])
    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    # Use GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Optimizer
    optimizer = torch.optim.AdamW(model.parameters(), lr=3e-5)

    # Training loop
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for batch in train_dataloader:
            input_ids, labels = [b.to(device) for b in batch]

            optimizer.zero_grad()
            outputs = model(input_ids=input_ids, labels=labels)
            loss = outputs.loss
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_dataloader)
        print(f"✅ Epoch {epoch+1} for {schema_file}, Average Loss: {avg_loss:.4f}")

        # Stop training if loss reaches threshold
        if avg_loss < early_stop_loss_threshold:
            print(f"🎯 Loss reached {avg_loss:.4f}, stopping early for {schema_file}!")
            break

    # Save the fine-tuned model for this schema part
    model_path = os.path.join(MODEL_BASE_PATH, f"fine_tuned_sql_model_part_{idx+1}")
    os.makedirs(model_path, exist_ok=True)

    model.save_pretrained(model_path)
    tokenizer.save_pretrained(model_path)

    print(f"✅ Model trained on {schema_file} and saved at: {model_path}")

print("🎉 All schema parts processed successfully!")
# Out:
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# ⚠️ Warning: No queries found for 'CrowdStrike - Compliance', skipping...
# ✅ Training Data Loaded from database_schema_part_1.json: 6 queries ready for training.
# 🔹 Using max_length=351 for this schema part.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# ✅ Epoch 1 for database_schema_part_1.json, Average Loss: 11.0932
# ✅ Epoch 2 for database_schema_part_1.json, Average Loss: 8.8583
# ✅ Epoch 3 for database_schema_part_1.json, Average Loss: 6.6956
# ✅ Epoch 4 for database_schema_part_1.json, Average Loss: 5.4014
# ✅ Epoch 5 for database_schema_part_1.json, Average Loss: 4.7012
# ✅ Epoch 6 for database_schema_part_1.json, Average Loss: 4.3572
# ✅ Epoch 7 for database_schema_part_1.json, Average Loss: 4.1130
# ✅ Epoch 8 for database_schema_part_1.json, Average Loss: 4.0384
# ✅ Epoch 9 for database_schema_part_1.json, Average Loss: 3.8074
# ✅ Epoch 10 for database_schema_part_1.json, Average Loss: 3.6375
# ✅ Epoch 11 for database_schema_part_1.json, Average Loss: 3.5307
# ✅ Epoch 12 for database_schema_part_1.json, Average Loss: 3.4514
# ✅ Epoch 13 for database_schema_part_1.json, Average Loss: 3.3672
# ✅ Epoch 14 for database_schema_part_1.json, Average Loss: 3.6987
# ✅ Epoch 15 for database_schema_part_1.json, Average Loss: 3.1312
# ✅ Epoch 16 for database_schema_part_1.json, Average Loss: 3.1366
# ✅ Epoch 17 for database_schema_part_1.json, Average Loss: 3.0508
# ✅ Epoch 18 for database_schema_part_1.json, Average Loss: 2.9371
# ✅ Epoch 19 for database_schema_part_1.json, Average Loss: 2.9328
# ✅ Epoch 20 for database_schema_part_1.json, Average Loss: 2.8483
# ✅ Epoch 21 for database_schema_part_1.json, Average Loss: 2.7828
# ✅ Epoch 22 for database_schema_part_1.json, Average Loss: 2.6916
# ✅ Epoch 23 for database_schema_part_1.json, Average Loss: 2.6495
# ✅ Epoch 24 for database_schema_part_1.json, Average Loss: 2.6433
# ✅ Epoch 25 for database_schema_part_1.json, Average Loss: 2.5568
# ✅ Epoch 26 for database_schema_part_1.json, Average Loss: 2.4833
# ✅ Epoch 27 for database_schema_part_1.json, Average Loss: 2.4990
# ✅ Epoch 28 for database_schema_part_1.json, Average Loss: 2.4337
# ✅ Epoch 29 for database_schema_part_1.json, Average Loss: 2.3867
# ✅ Epoch 30 for database_schema_part_1.json, Average Loss: 2.2866
# ✅ Epoch 31 for database_schema_part_1.json, Average Loss: 2.3032
# ✅ Epoch 32 for database_schema_part_1.json, Average Loss: 2.2534
# ✅ Epoch 33 for database_schema_part_1.json, Average Loss: 2.2186
# ✅ Epoch 34 for database_schema_part_1.json, Average Loss: 2.1576
# ✅ Epoch 35 for database_schema_part_1.json, Average Loss: 2.1594
# ✅ Epoch 36 for database_schema_part_1.json, Average Loss: 2.0858
# ✅ Epoch 37 for database_schema_part_1.json, Average Loss: 2.0912
# ✅ Epoch 38 for database_schema_part_1.json, Average Loss: 2.0134
# ✅ Epoch 39 for database_schema_part_1.json, Average Loss: 2.0725
# ✅ Epoch 40 for database_schema_part_1.json, Average Loss: 1.9357
# ✅ Epoch 41 for database_schema_part_1.json, Average Loss: 1.9735
# ✅ Epoch 42 for database_schema_part_1.json, Average Loss: 1.9149
# ✅ Epoch 43 for database_schema_part_1.json, Average Loss: 1.8993
# ✅ Epoch 44 for database_schema_part_1.json, Average Loss: 1.8554
# ✅ Epoch 45 for database_schema_part_1.json, Average Loss: 1.8301
# ✅ Epoch 46 for database_schema_part_1.json, Average Loss: 1.7692
# ✅ Epoch 47 for database_schema_part_1.json, Average Loss: 1.7562
# ✅ Epoch 48 for database_schema_part_1.json, Average Loss: 1.7255
# ✅ Epoch 49 for database_schema_part_1.json, Average Loss: 1.7145
# ✅ Epoch 50 for database_schema_part_1.json, Average Loss: 1.6676
# ✅ Epoch 51 for database_schema_part_1.json, Average Loss: 1.6600
# ✅ Epoch 52 for database_schema_part_1.json, Average Loss: 1.6330
# ✅ Epoch 53 for database_schema_part_1.json, Average Loss: 1.6287
# ✅ Epoch 54 for database_schema_part_1.json, Average Loss: 1.5623
# ✅ Epoch 55 for database_schema_part_1.json, Average Loss: 1.6050
# ✅ Epoch 56 for database_schema_part_1.json, Average Loss: 1.5373
# ✅ Epoch 57 for database_schema_part_1.json, Average Loss: 1.5329
# ✅ Epoch 58 for database_schema_part_1.json, Average Loss: 1.5367
# ✅ Epoch 59 for database_schema_part_1.json, Average Loss: 1.4243
# ✅ Epoch 60 for database_schema_part_1.json, Average Loss: 1.4291
# ✅ Epoch 61 for database_schema_part_1.json, Average Loss: 1.4076
# ✅ Epoch 62 for database_schema_part_1.json, Average Loss: 1.3765
# ✅ Epoch 63 for database_schema_part_1.json, Average Loss: 1.3837
# ✅ Epoch 64 for database_schema_part_1.json, Average Loss: 1.3257
# ✅ Epoch 65 for database_schema_part_1.json, Average Loss: 1.3433
# ✅ Epoch 66 for database_schema_part_1.json, Average Loss: 1.3057
# ✅ Epoch 67 for database_schema_part_1.json, Average Loss: 1.2658
# ✅ Epoch 68 for database_schema_part_1.json, Average Loss: 1.2508
# ✅ Epoch 69 for database_schema_part_1.json, Average Loss: 1.2562
# ✅ Epoch 70 for database_schema_part_1.json, Average Loss: 1.2059
# ✅ Epoch 71 for database_schema_part_1.json, Average Loss: 1.1765
# ✅ Epoch 72 for database_schema_part_1.json, Average Loss: 1.1810
# ✅ Epoch 73 for database_schema_part_1.json, Average Loss: 1.1639
# ✅ Epoch 74 for database_schema_part_1.json, Average Loss: 1.1038
# ✅ Epoch 75 for database_schema_part_1.json, Average Loss: 1.1148
# ✅ Epoch 76 for database_schema_part_1.json, Average Loss: 1.0974
# ✅ Epoch 77 for database_schema_part_1.json, Average Loss: 1.0504
# ✅ Epoch 78 for database_schema_part_1.json, Average Loss: 1.0364
# ✅ Epoch 79 for database_schema_part_1.json, Average Loss: 1.0322
# ✅ Epoch 80 for database_schema_part_1.json, Average Loss: 1.0004
# ✅ Epoch 81 for database_schema_part_1.json, Average Loss: 1.0143
# ✅ Epoch 82 for database_schema_part_1.json, Average Loss: 0.9684
# ✅ Epoch 83 for database_schema_part_1.json, Average Loss: 0.9724
# ✅ Epoch 84 for database_schema_part_1.json, Average Loss: 0.9576
# ✅ Epoch 85 for database_schema_part_1.json, Average Loss: 0.9135
# ✅ Epoch 86 for database_schema_part_1.json, Average Loss: 0.9432
# ✅ Epoch 87 for database_schema_part_1.json, Average Loss: 0.8795
# ✅ Epoch 88 for database_schema_part_1.json, Average Loss: 0.9130
# ✅ Epoch 89 for database_schema_part_1.json, Average Loss: 0.8859
# ✅ Epoch 90 for database_schema_part_1.json, Average Loss: 0.8475
# ✅ Epoch 91 for database_schema_part_1.json, Average Loss: 0.8568
# ✅ Epoch 92 for database_schema_part_1.json, Average Loss: 0.8354
# ✅ Epoch 93 for database_schema_part_1.json, Average Loss: 0.8421
# ✅ Epoch 94 for database_schema_part_1.json, Average Loss: 0.7946
# ✅ Epoch 95 for database_schema_part_1.json, Average Loss: 0.8074
# ✅ Epoch 96 for database_schema_part_1.json, Average Loss: 0.8307
# ✅ Epoch 97 for database_schema_part_1.json, Average Loss: 0.8058
# ✅ Epoch 98 for database_schema_part_1.json, Average Loss: 0.7758
# ✅ Epoch 99 for database_schema_part_1.json, Average Loss: 0.7613
# ✅ Epoch 100 for database_schema_part_1.json, Average Loss: 0.7244
# ✅ Model trained on database_schema_part_1.json and saved at: fine_tuned_models/fine_tuned_sql_model_part_1
# ✅ Training Data Loaded from database_schema_part_2.json: 7 queries ready for training.
# 🔹 Using max_length=389 for this schema part.
# ✅ Epoch 1 for database_schema_part_2.json, Average Loss: 2.8755
# ✅ Epoch 2 for database_schema_part_2.json, Average Loss: 1.3329
# ✅ Epoch 3 for database_schema_part_2.json, Average Loss: 1.5087
# ✅ Epoch 4 for database_schema_part_2.json, Average Loss: 1.3497
# ✅ Epoch 5 for database_schema_part_2.json, Average Loss: 1.9010
# ✅ Epoch 6 for database_schema_part_2.json, Average Loss: 1.4374
# ✅ Epoch 7 for database_schema_part_2.json, Average Loss: 1.9731
# ✅ Epoch 8 for database_schema_part_2.json, Average Loss: 1.9753
# ✅ Epoch 9 for database_schema_part_2.json, Average Loss: 1.8136
# ✅ Epoch 10 for database_schema_part_2.json, Average Loss: 1.0210
# ✅ Epoch 11 for database_schema_part_2.json, Average Loss: 1.1212
# ✅ Epoch 12 for database_schema_part_2.json, Average Loss: 1.4962
# ✅ Epoch 13 for database_schema_part_2.json, Average Loss: 1.5985
# ✅ Epoch 14 for database_schema_part_2.json, Average Loss: 1.0062
# ✅ Epoch 15 for database_schema_part_2.json, Average Loss: 1.8862
# ✅ Epoch 16 for database_schema_part_2.json, Average Loss: 1.0098
# ✅ Epoch 17 for database_schema_part_2.json, Average Loss: 1.4044
# ✅ Epoch 18 for database_schema_part_2.json, Average Loss: 1.6990
# ✅ Epoch 19 for database_schema_part_2.json, Average Loss: 1.2611
# ✅ Epoch 20 for database_schema_part_2.json, Average Loss: 1.3266
# ✅ Epoch 21 for database_schema_part_2.json, Average Loss: 2.8709
# ✅ Epoch 22 for database_schema_part_2.json, Average Loss: 1.2510
# ✅ Epoch 23 for database_schema_part_2.json, Average Loss: 0.8709
# ✅ Epoch 24 for database_schema_part_2.json, Average Loss: 1.2177
# ✅ Epoch 25 for database_schema_part_2.json, Average Loss: 1.2866
# ✅ Epoch 26 for database_schema_part_2.json, Average Loss: 0.9443
# ✅ Epoch 27 for database_schema_part_2.json, Average Loss: 1.2130
# ✅ Epoch 28 for database_schema_part_2.json, Average Loss: 0.9705
# ✅ Epoch 29 for database_schema_part_2.json, Average Loss: 1.4097
# ✅ Epoch 30 for database_schema_part_2.json, Average Loss: 1.2710
# ✅ Epoch 31 for database_schema_part_2.json, Average Loss: 0.7848
# ✅ Epoch 32 for database_schema_part_2.json, Average Loss: 0.7267
# ✅ Epoch 33 for database_schema_part_2.json, Average Loss: 0.8270
# ✅ Epoch 34 for database_schema_part_2.json, Average Loss: 0.8326
# ✅ Epoch 35 for database_schema_part_2.json, Average Loss: 0.6752
# ✅ Epoch 36 for database_schema_part_2.json, Average Loss: 0.8217
# ✅ Epoch 37 for database_schema_part_2.json, Average Loss: 1.2166
# ✅ Epoch 38 for database_schema_part_2.json, Average Loss: 0.6297
# ✅ Epoch 39 for database_schema_part_2.json, Average Loss: 0.6913
# ✅ Epoch 40 for database_schema_part_2.json, Average Loss: 0.6746
# ✅ Epoch 41 for database_schema_part_2.json, Average Loss: 0.6277
# ✅ Epoch 42 for database_schema_part_2.json, Average Loss: 0.6208
# ✅ Epoch 43 for database_schema_part_2.json, Average Loss: 0.6051
# ✅ Epoch 44 for database_schema_part_2.json, Average Loss: 0.6442
# ✅ Epoch 45 for database_schema_part_2.json, Average Loss: 0.5795
# ✅ Epoch 46 for database_schema_part_2.json, Average Loss: 0.5720
# ✅ Epoch 47 for database_schema_part_2.json, Average Loss: 0.6653
# ✅ Epoch 48 for database_schema_part_2.json, Average Loss: 0.5825
# ✅ Epoch 49 for database_schema_part_2.json, Average Loss: 0.6689
# ✅ Epoch 50 for database_schema_part_2.json, Average Loss: 0.6455
# ✅ Epoch 51 for database_schema_part_2.json, Average Loss: 0.5491
# ✅ Epoch 52 for database_schema_part_2.json, Average Loss: 0.5194
# ✅ Epoch 53 for database_schema_part_2.json, Average Loss: 0.5304
# ✅ Epoch 54 for database_schema_part_2.json, Average Loss: 0.5211
# ✅ Epoch 55 for database_schema_part_2.json, Average Loss: 0.5886
# ✅ Epoch 56 for database_schema_part_2.json, Average Loss: 0.5505
# ✅ Epoch 57 for database_schema_part_2.json, Average Loss: 0.5637
# ✅ Epoch 58 for database_schema_part_2.json, Average Loss: 0.4740
# 🎯 Loss reached 0.4740, stopping early for database_schema_part_2.json!
# ✅ Model trained on database_schema_part_2.json and saved at: fine_tuned_models/fine_tuned_sql_model_part_2
# ⚠️ Warning: No queries found for 'JAMF - Compliance', skipping...
# ✅ Training Data Loaded from database_schema_part_3.json: 6 queries ready for training.
# 🔹 Using max_length=308 for this schema part.
# ✅ Epoch 1 for database_schema_part_3.json, Average Loss: 1.0773
# ✅ Epoch 2 for database_schema_part_3.json, Average Loss: 0.9643
# ✅ Epoch 3 for database_schema_part_3.json, Average Loss: 0.9619
# ✅ Epoch 4 for database_schema_part_3.json, Average Loss: 0.9170
# ✅ Epoch 5 for database_schema_part_3.json, Average Loss: 0.8779
# ✅ Epoch 6 for database_schema_part_3.json, Average Loss: 0.8194
# ✅ Epoch 7 for database_schema_part_3.json, Average Loss: 0.8055
# ✅ Epoch 8 for database_schema_part_3.json, Average Loss: 0.7396
# ✅ Epoch 9 for database_schema_part_3.json, Average Loss: 0.7422
# ✅ Epoch 10 for database_schema_part_3.json, Average Loss: 0.7177
# ✅ Epoch 11 for database_schema_part_3.json, Average Loss: 0.6980
# ✅ Epoch 12 for database_schema_part_3.json, Average Loss: 0.6576
# ✅ Epoch 13 for database_schema_part_3.json, Average Loss: 0.6618
# ✅ Epoch 14 for database_schema_part_3.json, Average Loss: 0.6247
# ✅ Epoch 15 for database_schema_part_3.json, Average Loss: 0.6395
# ✅ Epoch 16 for database_schema_part_3.json, Average Loss: 0.6122
# ✅ Epoch 17 for database_schema_part_3.json, Average Loss: 0.5759
# ✅ Epoch 18 for database_schema_part_3.json, Average Loss: 0.5678
# ✅ Epoch 19 for database_schema_part_3.json, Average Loss: 0.5418
# ✅ Epoch 20 for database_schema_part_3.json, Average Loss: 0.5492
# ✅ Epoch 21 for database_schema_part_3.json, Average Loss: 0.5256
# ✅ Epoch 22 for database_schema_part_3.json, Average Loss: 0.5143
# ✅ Epoch 23 for database_schema_part_3.json, Average Loss: 0.4972
# 🎯 Loss reached 0.4972, stopping early for database_schema_part_3.json!
# ✅ Model trained on database_schema_part_3.json and saved at: fine_tuned_models/fine_tuned_sql_model_part_3
# ⚠️ Warning: No queries found for 'Unknown', skipping...
# ✅ Training Data Loaded from database_schema_part_4.json: 6 queries ready for training.
# 🔹 Using max_length=710 for this schema part.
# ✅ Epoch 1 for database_schema_part_4.json, Average Loss: 1.1153
# ✅ Epoch 2 for database_schema_part_4.json, Average Loss: 1.0566
# ✅ Epoch 3 for database_schema_part_4.json, Average Loss: 0.9920
# ✅ Epoch 4 for database_schema_part_4.json, Average Loss: 0.9461
# ✅ Epoch 5 for database_schema_part_4.json, Average Loss: 0.9303
# ✅ Epoch 6 for database_schema_part_4.json, Average Loss: 0.8762
# ✅ Epoch 7 for database_schema_part_4.json, Average Loss: 0.8639
# ✅ Epoch 8 for database_schema_part_4.json, Average Loss: 0.8250
# ✅ Epoch 9 for database_schema_part_4.json, Average Loss: 0.8146
# ✅ Epoch 10 for database_schema_part_4.json, Average Loss: 0.7738
# ✅ Epoch 11 for database_schema_part_4.json, Average Loss: 0.7395
# ✅ Epoch 12 for database_schema_part_4.json, Average Loss: 0.7440
# ✅ Epoch 13 for database_schema_part_4.json, Average Loss: 0.7245
# ✅ Epoch 14 for database_schema_part_4.json, Average Loss: 0.7118
# ✅ Epoch 15 for database_schema_part_4.json, Average Loss: 0.6771
# ✅ Epoch 16 for database_schema_part_4.json, Average Loss: 0.6800
# ✅ Epoch 17 for database_schema_part_4.json, Average Loss: 0.6643
# ✅ Epoch 18 for database_schema_part_4.json, Average Loss: 0.6250
# ✅ Epoch 19 for database_schema_part_4.json, Average Loss: 0.6099
# ✅ Epoch 20 for database_schema_part_4.json, Average Loss: 0.6015
# ✅ Epoch 21 for database_schema_part_4.json, Average Loss: 0.6007
# ✅ Epoch 22 for database_schema_part_4.json, Average Loss: 0.5866
# ✅ Epoch 23 for database_schema_part_4.json, Average Loss: 0.5660
# ✅ Epoch 24 for database_schema_part_4.json, Average Loss: 0.5630
# ✅ Epoch 25 for database_schema_part_4.json, Average Loss: 0.5253
# ✅ Epoch 26 for database_schema_part_4.json, Average Loss: 0.5385
# ✅ Epoch 27 for database_schema_part_4.json, Average Loss: 0.5222
# ✅ Epoch 28 for database_schema_part_4.json, Average Loss: 0.5158
# ✅ Epoch 29 for database_schema_part_4.json, Average Loss: 0.5039
# ✅ Epoch 30 for database_schema_part_4.json, Average Loss: 0.4947
# 🎯 Loss reached 0.4947, stopping early for database_schema_part_4.json!
# ✅ Model trained on database_schema_part_4.json and saved at: fine_tuned_models/fine_tuned_sql_model_part_4
# ⚠️ Warning: No queries found for 'Sapphire Compliance', skipping...
# ✅ Training Data Loaded from database_schema_part_5.json: 6 queries ready for training.
# 🔹 Using max_length=341 for this schema part.
# ✅ Epoch 1 for database_schema_part_5.json, Average Loss: 0.9734
# ✅ Epoch 2 for database_schema_part_5.json, Average Loss: 0.8914
# ✅ Epoch 3 for database_schema_part_5.json, Average Loss: 0.8484
# ✅ Epoch 4 for database_schema_part_5.json, Average Loss: 0.8125
# ✅ Epoch 5 for database_schema_part_5.json, Average Loss: 0.7506
# ✅ Epoch 6 for database_schema_part_5.json, Average Loss: 0.7181
# ✅ Epoch 7 for database_schema_part_5.json, Average Loss: 0.6968
# ✅ Epoch 8 for database_schema_part_5.json, Average Loss: 0.6492
# ✅ Epoch 9 for database_schema_part_5.json, Average Loss: 0.6342
# ✅ Epoch 10 for database_schema_part_5.json, Average Loss: 0.6088
# ✅ Epoch 11 for database_schema_part_5.json, Average Loss: 0.5613
# ✅ Epoch 12 for database_schema_part_5.json, Average Loss: 0.5189
# ✅ Epoch 13 for database_schema_part_5.json, Average Loss: 0.5032
# ✅ Epoch 14 for database_schema_part_5.json, Average Loss: 0.4927
# 🎯 Loss reached 0.4927, stopping early for database_schema_part_5.json!
# ✅ Model trained on database_schema_part_5.json and saved at: fine_tuned_models/fine_tuned_sql_model_part_5
# 🎉 All schema parts processed successfully!
